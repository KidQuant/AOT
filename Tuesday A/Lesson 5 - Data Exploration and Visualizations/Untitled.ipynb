# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

df = pd.read_csv('data exploration_assignment_dataset.csv')

# %%
df.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
# 2           No  26.58     Yes              No     No            20.0
# 3           No  24.21      No              No     No             0.0
# 4           No  23.71      No              No     No            28.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0          30.0          No  Female        55-59  White      Yes
# 1           0.0          No  Female  80 or older  White       No
# 2          30.0          No    Male        65-69  White      Yes
# 3           0.0          No  Female        75-79  White       No
# 4           0.0         Yes  Female        40-44  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good        5.0    Yes            No        Yes
# ...

# %%
data = df.groupby('Sex')['BMI'].mean()
data.plot.bar()
# Out:
# <Axes: xlabel='Sex'>

# %%
data2 = df.groupby('AgeCategory')['BMI'].mean()
plt.pie(data2, labels=data2.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x1d541cc02f0>,
# ...
#  [Text(1.0734206346781134, 0.24035003858380444, '18-24'),
#   Text(0.8571960248856053, 0.6893583791616062, '25-29'),
#   Text(0.44208635216271397, 1.0072535218262904, '30-34'),
#   Text(-0.0836919618658895, 1.096811586152808, '35-39'),
#   Text(-0.5958140452104759, 0.9246651412970693, '40-44'),
#   Text(-0.9671215547396415, 0.5240953141919692, '45-49'),
#   Text(-1.0999722781062917, -0.007809442851768322, '50-54'),
#   Text(-0.9613623620042347, -0.5345862034523888, '55-59'),
#   Text(-0.5918059061435226, -0.9272355523024581, '60-64'),
#   Text(-0.08402565210571333, -1.0967860729368375, '65-69'),
#   Text(0.43808978910176044, -1.0089981846786322, '70-74'),
#   Text(0.8523486561375235, -0.6953429142376859, '75-79'),
#   Text(1.0724777187220507, -0.24452309266150335, '80 or older')])

# %%
plt.hist(df['BMI'], bins=25)
# Out:
# (array([3.7900e+02, 5.3730e+03, 3.4403e+04, 7.2132e+04, 7.7103e+04,
#         5.6643e+04, 3.3416e+04, 1.8951e+04, 9.7960e+03, 5.3840e+03,
#         2.9190e+03, 1.5460e+03, 7.7700e+02, 3.6800e+02, 2.1500e+02,
#         1.6400e+02, 6.6000e+01, 4.8000e+01, 4.0000e+01, 3.0000e+01,
#         1.2000e+01, 1.4000e+01, 7.0000e+00, 1.0000e+00, 8.0000e+00]),
#  array([12.02  , 15.3332, 18.6464, 21.9596, 25.2728, 28.586 , 31.8992,
#         35.2124, 38.5256, 41.8388, 45.152 , 48.4652, 51.7784, 55.0916,
#         58.4048, 61.718 , 65.0312, 68.3444, 71.6576, 74.9708, 78.284 ,
#         81.5972, 84.9104, 88.2236, 91.5368, 94.85  ]),
#  <BarContainer object of 25 artists>)

# %%
import seaborn as sns

sns.boxplot(x=df['BMI'], showfliers =False)
# Out:
# <Axes: xlabel='BMI'>
