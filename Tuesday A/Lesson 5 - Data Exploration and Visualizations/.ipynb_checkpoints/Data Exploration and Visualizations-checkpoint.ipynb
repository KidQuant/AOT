# %% [markdown]
# # Data Exploration and Visualizations

# %% [markdown]
# ## Line Charts

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
plt.style.use('seaborn-v0_8-whitegrid')

# %%
fig = plt.figure()
ax = plt.axes()
x = np.linspace(0, 10, 1000)
ax.plot(x, np.sin(x))

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))

# %% [markdown]
# ### Adjusting Line Colors and Styles

# %%
plt.plot(x, np.sin(x - 0), color='blue') # specify color by name
plt.plot(x, np.sin(x - 1), color='g') # short color code (rgbcmyk)
plt.plot(x, np.sin(x - 2), color='0.75') # Grayscale between 0 and 1
plt.plot(x, np.sin(x - 3), color='#FFDD44') # Hex code (RRGGBB from 00 to FF)
plt.plot(x, np.sin(x - 4), color=(1.0,0.2,0.3)) # RGB tuple, values 0 and 1
plt.plot(x, np.sin(x - 5), color='chartreuse'); # all HTML color names supported

# %%
plt.plot(x, x + 0, linestyle='solid')
plt.plot(x, x + 1, linestyle='dashed')
plt.plot(x, x + 2, linestyle='dashdot')
plt.plot(x, x + 3, linestyle='dotted');
# For short, you can use the following codes:
plt.plot(x, x + 4, linestyle='-') # solid
plt.plot(x, x + 5, linestyle='--') # dashed
plt.plot(x, x + 6, linestyle='-.') # dashdot
plt.plot(x, x + 7, linestyle=':');

# %% [markdown]
# ### Changing Axes

# %%
plt.plot(x, np.sin(x))

# %%
plt.plot(x, np.sin(x))
plt.xlim(0, 10)
plt.ylim(-1.5, 1.5)
# Out:
# (-1.5, 1.5)

# %% [markdown]
# ### Labeling Plots

# %%
plt.plot(x, np.sin(x))
plt.xlim(0, 10)
plt.ylim(-1.5, 1.5)
plt.title('A Sine Curve')
plt.xlabel('x')
plt.ylabel('f(x)')
# Out:
# Text(0, 0.5, 'f(x)')

# %%
plt.plot(x, np.sin(x), '-g', label='sin(x)')
plt.plot(x, np.cos(x), ':b', label='cos(x)')
plt.title('Trig Functions')
plt.xlim(0, 10)
plt.ylim(-1.5, 1.5)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.show()

# %% [markdown]
# ## Bar Chart

# %%
# dictionary object for the data
data = {'C':20, 'C++':15, 'Java':30, 
        'Python':35} 

# converts the keys and values to list objects 
courses = list(data.keys())
values = list(data.values())

# changes the dimenions of the chart
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(courses, values, color ='maroon', 
        width = 0.9)
 
# labels and titles
plt.xlabel("Courses offered")
plt.ylabel("No. of students enrolled")
plt.title("Students enrolled in different courses")
plt.show()

# %% [markdown]
# ## Pie Chart

# %%
# a list of labels and values
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1247fd6ea10>,
#   <matplotlib.patches.Wedge at 0x1247fdb2010>,
#   <matplotlib.patches.Wedge at 0x1247fdb3650>,
#   <matplotlib.patches.Wedge at 0x1247fdb2910>],
#  [Text(0.9801071672559598, 0.4993895680663527, 'Frogs'),
#   Text(-0.33991877217145816, 1.046162142464278, 'Hogs'),
#   Text(-0.49938947630209474, -0.9801072140121813, 'Dogs'),
#   Text(1.0461621822461364, -0.3399186497354948, 'Logs')],
#  [Text(0.5346039094123416, 0.2723943098543742, '15.0%'),
#   Text(-0.18541023936624987, 0.5706338958896061, '30.0%'),
#   Text(-0.27239425980114257, -0.5346039349157352, '45.0%'),
#   Text(0.5706339175888016, -0.18541017258299716, '10.0%')])

# %% [markdown]
# ## Scatter Plots

# %%
from sklearn.datasets import load_iris
iris = load_iris()
features = iris.data.T

# %%
import pandas as pd
# Out:
# C:\Users\drebi\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df = pd.DataFrame(load_iris().data, columns=load_iris().feature_names)
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
plt.scatter(features[0], features[1],
           alpha = .2,
           s=features[3] *100,
            c=iris.target,
           cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1])
# Out:
# Text(0, 0.5, 'sepal width (cm)')

# %% [markdown]
# ### The Average

# %%
import random

# %%
int_list = []

for i in range(11):
    int_list.append(random.randint(3,12))
print(int_list)
# Out:
# [9, 6, 12, 3, 7, 4, 7, 9, 7, 12, 8]

# %%
np.sum(int_list)/len(int_list)
# Out:
# 7.636363636363637

# %% [markdown]
# ### Median

# %%
np.median(int_list)
# Out:
# 7.0

# %%
int_list.sort()
print(int_list)
# Out:
# [3, 4, 6, 7, 7, 7, 8, 9, 9, 12, 12]

# %% [markdown]
# ## Histogram

# %%
data = np.random.randn(1000)
plt.hist(data, edgecolor='black')
# Out:
# (array([  3.,   4.,  51., 114., 243., 289., 194.,  76.,  23.,   3.]),
#  array([-3.76951689, -3.05914539, -2.34877388, -1.63840238, -0.92803087,
#         -0.21765937,  0.49271214,  1.20308365,  1.91345515,  2.62382666,
#          3.33419816]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data, bins=25, alpha=0.5, histtype='stepfilled', color='steelblue')
# Out:
# (array([  1.,   2.,   1.,   0.,   3.,  15.,  19.,  39.,  33.,  59.,  83.,
#         101., 122., 102., 124.,  86.,  81.,  45.,  39.,  19.,  20.,   2.,
#           3.,   0.,   1.]),
#  array([-3.76951689, -3.48536829, -3.20121969, -2.91707109, -2.63292248,
#         -2.34877388, -2.06462528, -1.78047668, -1.49632808, -1.21217947,
#         -0.92803087, -0.64388227, -0.35973367, -0.07558506,  0.20856354,
#          0.49271214,  0.77686074,  1.06100934,  1.34515795,  1.62930655,
#          1.91345515,  2.19760375,  2.48175236,  2.76590096,  3.05004956,
#          3.33419816]),
#  [<matplotlib.patches.Polygon at 0x124308f32d0>])

# %%
x1 = np.random.normal(0, 0.6, 1000)
x2 = np.random.normal(-3, 1, 1000)
x3 = np.random.normal(3, 2, 1000)
kwargs = dict(histtype='stepfilled', alpha=0.3, bins=20)
plt.hist(x1, **kwargs)
plt.hist(x2, **kwargs)
plt.hist(x3, **kwargs)
# Out:
# (array([  1.,   0.,   1.,   3.,   9.,  19.,  38.,  64.,  73.,  89., 123.,
#         133., 139., 101.,  83.,  63.,  27.,  20.,  10.,   4.]),
#  array([-4.92925236, -4.24131981, -3.55338726, -2.8654547 , -2.17752215,
#         -1.4895896 , -0.80165705, -0.11372449,  0.57420806,  1.26214061,
#          1.95007316,  2.63800571,  3.32593827,  4.01387082,  4.70180337,
#          5.38973592,  6.07766848,  6.76560103,  7.45353358,  8.14146613,
#          8.82939868]),
#  [<matplotlib.patches.Polygon at 0x1242cbae250>])

# %%
import seaborn as sns
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips['total_bill'].mean()
# Out:
# 19.78594262295082

# %%
tips['total_bill'].median()
# Out:
# 17.795

# %%
tips['total_bill'].std()
# Out:
# 8.902411954856856

# %%
plt.hist(tips['total_bill'], bins=15, edgecolor='black')
# Out:
# (array([ 2., 10., 37., 42., 49., 28., 24., 14., 12., 10.,  4.,  5.,  2.,
#          1.,  4.]),
#  array([ 3.07      ,  6.25266667,  9.43533333, 12.618     , 15.80066667,
#         18.98333333, 22.166     , 25.34866667, 28.53133333, 31.714     ,
#         34.89666667, 38.07933333, 41.262     , 44.44466667, 47.62733333,
#         50.81      ]),
#  <BarContainer object of 15 artists>)

# %%
tips['total_bill'].max()
# Out:
# 50.81

# %%
tips['total_bill'].min()
# Out:
# 3.07

# %% [markdown]
# ## Boxplot

# %%
sns.boxplot(x=tips['total_bill'])
# Out:
# <Axes: xlabel='total_bill'>
