# %% [markdown]
# # Data Exploration and Visualizations

# %% [markdown]
# ## Line Charts

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('seaborn-v0_8-whitegrid') # optional
# %matplotlib inline

# %%
fig = plt.figure()
ax = plt.axes()
x = np.linspace(0, 10, 1000)
ax.plot(x, np.sin(x))

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))

# %% [markdown]
# ### Adjusting Line Colors and Styles

# %%
plt.plot(x, np.sin(x - 0), color='blue') # specify color by name
plt.plot(x, np.sin(x - 1), color='g') # short color code (rgbcmyk)
plt.plot(x, np.sin(x - 2), color='0.75') # Grayscale between 0 and 1
plt.plot(x, np.sin(x - 3), color='#FFDD44') # Hex code (RRGGBB from 00 to FF)
plt.plot(x, np.sin(x - 4), color=(1.0,0.2,0.3)) # RGB tuple, values 0 and 1
plt.plot(x, np.sin(x - 5), color='chartreuse'); # all HTML color names supported

# %%
plt.plot(x, x + 0, linestyle='solid')
plt.plot(x, x + 1, linestyle='dashed')
plt.plot(x, x + 2, linestyle='dashdot')
plt.plot(x, x + 3, linestyle='dotted');
# For short, you can use the following codes:
plt.plot(x, x + 4, linestyle='-') # solid
plt.plot(x, x + 5, linestyle='--') # dashed
plt.plot(x, x + 6, linestyle='-.') # dashdot
plt.plot(x, x + 7, linestyle=':');

# %% [markdown]
# ### Changing Axes

# %%
plt.plot(x, np.sin(x))

# %%
plt.plot(x, np.sin(x))
plt.xlim(0, 10)
plt.ylim(-1.5, 1.5)
# Out:
# (-1.5, 1.5)

# %% [markdown]
# ### Labeling Plots

# %%
plt.plot(x, np.sin(x))
plt.xlim(0, 10)
plt.ylim(-1.5, 1.5)
plt.title('A Sine Curve')
plt.xlabel('x')
plt.ylabel('f(x)')
# Out:
# Text(0, 0.5, 'f(x)')

# %%
plt.plot(x, np.sin(x), color ='g', linestyle ='solid', label='sin(x)')
plt.plot(x, np.cos(x), ':b', label = 'cos(x)')
plt.xlim(0, 10)
plt.ylim(-1.5, 1.5)
plt.title('Trig Functions')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.show()

# %% [markdown]
# ## Bar Chart

# %%
# dictionary object for the data
data = {'C':20, 'C++':15, 'Java':30, 
        'Python':35} 

# converts the keys and values to list objects 
courses = list(data.keys())
values = list(data.values())

# changes the dimenions of the chart
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(courses, values, color ='maroon', 
        width = .4)
 
# labels and titles
plt.xlabel("Courses offered")
plt.ylabel("No. of students enrolled")
plt.title("Students enrolled in different courses")
plt.show()

# %% [markdown]
# ## Pie Chart

# %%
# a list of labels and values
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x20c44e61190>,
#   <matplotlib.patches.Wedge at 0x20c443c1850>,
#   <matplotlib.patches.Wedge at 0x20c44ead350>,
#   <matplotlib.patches.Wedge at 0x20c443c0890>],
#  [Text(0.9801071672559598, 0.4993895680663527, 'Frogs'),
#   Text(-0.33991877217145816, 1.046162142464278, 'Hogs'),
#   Text(-0.49938947630209474, -0.9801072140121813, 'Dogs'),
#   Text(1.0461621822461364, -0.3399186497354948, 'Logs')],
#  [Text(0.5346039094123416, 0.2723943098543742, '15.0%'),
#   Text(-0.18541023936624987, 0.5706338958896061, '30.0%'),
#   Text(-0.27239425980114257, -0.5346039349157352, '45.0%'),
#   Text(0.5706339175888016, -0.18541017258299716, '10.0%')])

# %% [markdown]
# ## Scatter Plots

# %%
from sklearn.datasets import load_iris
iris = load_iris()
features = iris.data.T

# %%
import pandas as pd
# Out:
# C:\Users\drebi\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df = pd.DataFrame(load_iris().data, columns=load_iris().feature_names)
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
plt.scatter(features[0],features[1],
           alpha=.2,
           s=features[3]*100,
           c=iris.target,
           cmap='viridis')

plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1])
# Out:
# Text(0, 0.5, 'sepal width (cm)')

# %% [markdown]
# ### The Average

# %%
import random

# %%
int_list = []

for i in range(11):
    int_list.append(random.randint(3, 12))

print(int_list)
# Out:
# [4, 4, 3, 3, 3, 9, 10, 12, 10, 10, 11]

# %%
np.sum(int_list)/ len(int_list)
# Out:
# 7.181818181818182

# %%
np.average(int_list)
# Out:
# 7.181818181818182

# %%
int_list.sort()
int_list
# Out:
# [3, 3, 3, 4, 4, 9, 10, 10, 10, 11, 12]

# %%
np.median(int_list)
# Out:
# 9.0

# %% [markdown]
# ### Median

# %% [markdown]
# ## Histogram

# %%
data = np.random.randn(1000)

# %%
plt.hist(data, edgecolor='black', 
         bins=25, 
         histtype='stepfilled', 
         color='steelblue')
# Out:
# (array([  1.,   2.,   6.,   4.,  14.,  16.,  36.,  38.,  60.,  59., 105.,
#         100., 113., 103.,  92.,  82.,  47.,  47.,  35.,   7.,  12.,  13.,
#           3.,   2.,   3.]),
#  array([-3.37783704, -3.11169187, -2.8455467 , -2.57940153, -2.31325637,
#         -2.0471112 , -1.78096603, -1.51482086, -1.2486757 , -0.98253053,
#         -0.71638536, -0.45024019, -0.18409502,  0.08205014,  0.34819531,
#          0.61434048,  0.88048565,  1.14663082,  1.41277598,  1.67892115,
#          1.94506632,  2.21121149,  2.47735666,  2.74350182,  3.00964699,
#          3.27579216]),
#  [<matplotlib.patches.Polygon at 0x20c4bdddad0>])

# %%
x1 = np.random.normal(0, 0.6, 1000)
x2 = np.random.normal(-3, 1, 1000)
x3 = np.random.normal(3, 2, 1000)
kwargs = dict(histtype='stepfilled', alpha=0.3, bins=20)
plt.hist(x1, **kwargs)
plt.hist(x2, **kwargs)
plt.hist(x3, **kwargs)
# Out:
# (array([  2.,   5.,   5.,  13.,  21.,  41.,  71.,  94., 102., 131., 128.,
#         129.,  92.,  66.,  49.,  27.,  15.,   4.,   2.,   3.]),
#  array([-3.56353839, -2.91436674, -2.2651951 , -1.61602345, -0.96685181,
#         -0.31768016,  0.33149149,  0.98066313,  1.62983478,  2.27900643,
#          2.92817807,  3.57734972,  4.22652136,  4.87569301,  5.52486466,
#          6.1740363 ,  6.82320795,  7.4723796 ,  8.12155124,  8.77072289,
#          9.41989453]),
#  [<matplotlib.patches.Polygon at 0x20c4be6c9d0>])

# %%
import seaborn as sns

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips['total_bill'].mean()
# Out:
# 19.78594262295082

# %%
tips['total_bill'].median()
# Out:
# 17.795

# %%
plt.hist(tips['total_bill'], bins=15, edgecolor='black')
# Out:
# (array([ 2., 10., 37., 42., 49., 28., 24., 14., 12., 10.,  4.,  5.,  2.,
#          1.,  4.]),
#  array([ 3.07      ,  6.25266667,  9.43533333, 12.618     , 15.80066667,
#         18.98333333, 22.166     , 25.34866667, 28.53133333, 31.714     ,
#         34.89666667, 38.07933333, 41.262     , 44.44466667, 47.62733333,
#         50.81      ]),
#  <BarContainer object of 15 artists>)

# %%
tips['total_bill'].max()
# Out:
# 50.81

# %% [markdown]
# ## Boxplot
