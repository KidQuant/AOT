# %%
import pandas as pd

df = pd.read_csv('data curation_activity_dataset.csv')
df
# Out:
#      id first_name last_name                             email    gender  \
# 0     1       Marj  Wasselin      MarjWasselin@datascience.AOT    Female
# 1     2    Kissiah     Lince      KissiahLince@datascience.AOT    Female
# 2     3  Margarita     Celle    MargaritaCelle@datascience.AOT    Female
# 3     4        Nat   Richens        NatRichens@datascience.AOT    Female
# 4     5     Jelene    Ripper      JeleneRipper@datascience.AOT  Bigender
# ..  ...        ...       ...                               ...       ...
# 95   96     Hollie  Westwood    HollieWestwood@datascience.AOT    Female
# 96   97    Carroll    Harmes     CarrollHarmes@datascience.AOT      Male
# 97   98   Zacharie  Houlston  ZacharieHoulston@datascience.AOT      Male
# 98   99      Gerda    Jevons       GerdaJevons@datascience.AOT    Female
# 99  100     Darren  Jellyman    DarrenJellyman@datascience.AOT      Male
#
#    loyalty_status  spend_2021 avg_rate
# 0            Gold     2822.87   $95.11
# ...

# %%
df.head(25)
# Out:
#     id  first_name  last_name                              email       gender  \
# 0    1        Marj   Wasselin       MarjWasselin@datascience.AOT       Female
# 1    2     Kissiah      Lince       KissiahLince@datascience.AOT       Female
# 2    3   Margarita      Celle     MargaritaCelle@datascience.AOT       Female
# 3    4         Nat    Richens         NatRichens@datascience.AOT       Female
# 4    5      Jelene     Ripper       JeleneRipper@datascience.AOT     Bigender
# 5    6         Tom  Mullender       TomMullender@datascience.AOT         Male
# 6    7       Sonny   Jerschke      SonnyJerschke@datascience.AOT         Male
# 7    8     Kearney    Hubeaux     KearneyHubeaux@datascience.AOT         Male
# 8    9       Vince    Mannock       VinceMannock@datascience.AOT         Male
# 9   10       Harry  Duckworth     HarryDuckworth@datascience.AOT         Male
# 10  11     Robbert       Kite        RobbertKite@datascience.AOT         Male
# ...

# %%
df.tail()
# Out:
#      id first_name last_name                             email  gender  \
# 95   96     Hollie  Westwood    HollieWestwood@datascience.AOT  Female
# 96   97    Carroll    Harmes     CarrollHarmes@datascience.AOT    Male
# 97   98   Zacharie  Houlston  ZacharieHoulston@datascience.AOT    Male
# 98   99      Gerda    Jevons       GerdaJevons@datascience.AOT  Female
# 99  100     Darren  Jellyman    DarrenJellyman@datascience.AOT    Male
#
#    loyalty_status  spend_2021 avg_rate
# 95       Platnium     3987.32   $71.97
# 96         Silver     2621.81  $193.14
# 97           Gold     2602.96  $115.64
# 98       Platnium     3841.46   $32.26
# 99            NaN     2717.84   $84.21

# %%
# df['first_name'].head()
df['last_name'].tail()
# Out:
# 95    Westwood
# 96      Harmes
# 97    Houlston
# 98      Jevons
# 99    Jellyman
# Name: last_name, dtype: object

# %%
df[0:6]
# Out:
#    id first_name  last_name                           email    gender  \
# 0   1       Marj   Wasselin    MarjWasselin@datascience.AOT    Female
# 1   2    Kissiah      Lince    KissiahLince@datascience.AOT    Female
# 2   3  Margarita      Celle  MargaritaCelle@datascience.AOT    Female
# 3   4        Nat    Richens      NatRichens@datascience.AOT    Female
# 4   5     Jelene     Ripper    JeleneRipper@datascience.AOT  Bigender
# 5   6        Tom  Mullender    TomMullender@datascience.AOT      Male
#
#   loyalty_status  spend_2021 avg_rate
# 0           Gold     2822.87   $95.11
# 1           Gold     2330.12   $34.13
# 2       Platnium     2797.42  $204.66
# 3            NaN     2487.10   $60.49
# 4         Silver     2370.85   $78.13
# 5       Platnium      542.91   $63.01

# %% [markdown]
# # DF.loc Method

# %%
df.loc[0]
# Out:
# id                                           1
# first_name                                Marj
# last_name                             Wasselin
# email             MarjWasselin@datascience.AOT
# gender                                  Female
# loyalty_status                            Gold
# spend_2021                             2822.87
# avg_rate                                $95.11
# Name: 0, dtype: object

# %%
# df.loc[0, ['first_name']]
# df.loc[0, ['first_name', 'email','gender']]
df.loc[:4, ['first_name','email','gender']]
# Out:
#   first_name                           email    gender
# 0       Marj    MarjWasselin@datascience.AOT    Female
# 1    Kissiah    KissiahLince@datascience.AOT    Female
# 2  Margarita  MargaritaCelle@datascience.AOT    Female
# 3        Nat      NatRichens@datascience.AOT    Female
# 4     Jelene    JeleneRipper@datascience.AOT  Bigender

# %% [markdown]
# # DF.iloc Method

# %%
df.iloc[0]
# Out:
# id                                           1
# first_name                                Marj
# last_name                             Wasselin
# email             MarjWasselin@datascience.AOT
# gender                                  Female
# loyalty_status                            Gold
# spend_2021                             2822.87
# avg_rate                                $95.11
# Name: 0, dtype: object

# %%
# df.loc[0, ['first_name', 'email','gender']]
df.iloc[0,[1, 3, 4]]
# Out:
# first_name                            Marj
# email         MarjWasselin@datascience.AOT
# gender                              Female
# Name: 0, dtype: object

# %%
#df.loc[:4, ['first_name','email','gender']]
df.iloc[:5, [1, 3, 4]]
# Out:
#   first_name                           email    gender
# 0       Marj    MarjWasselin@datascience.AOT    Female
# 1    Kissiah    KissiahLince@datascience.AOT    Female
# 2  Margarita  MargaritaCelle@datascience.AOT    Female
# 3        Nat      NatRichens@datascience.AOT    Female
# 4     Jelene    JeleneRipper@datascience.AOT  Bigender

# %%
df.loc[:4, ['first_name','email','gender']]
# Out:
#   first_name                           email    gender
# 0       Marj    MarjWasselin@datascience.AOT    Female
# 1    Kissiah    KissiahLince@datascience.AOT    Female
# 2  Margarita  MargaritaCelle@datascience.AOT    Female
# 3        Nat      NatRichens@datascience.AOT    Female
# 4     Jelene    JeleneRipper@datascience.AOT  Bigender

# %%
df.set_index('first_name')
# Out:
#              id last_name                             email    gender  \
# first_name
# Marj          1  Wasselin      MarjWasselin@datascience.AOT    Female
# Kissiah       2     Lince      KissiahLince@datascience.AOT    Female
# Margarita     3     Celle    MargaritaCelle@datascience.AOT    Female
# Nat           4   Richens        NatRichens@datascience.AOT    Female
# Jelene        5    Ripper      JeleneRipper@datascience.AOT  Bigender
# ...         ...       ...                               ...       ...
# Hollie       96  Westwood    HollieWestwood@datascience.AOT    Female
# Carroll      97    Harmes     CarrollHarmes@datascience.AOT      Male
# Zacharie     98  Houlston  ZacharieHoulston@datascience.AOT      Male
# Gerda        99    Jevons       GerdaJevons@datascience.AOT    Female
# Darren      100  Jellyman    DarrenJellyman@datascience.AOT      Male
#
#            loyalty_status  spend_2021 avg_rate
# first_name
# Marj                 Gold     2822.87   $95.11
# ...

# %%
df[df['loyalty_status'] == 'Gold'].head()
# Out:
#     id first_name last_name                             email  gender  \
# 0    1       Marj  Wasselin      MarjWasselin@datascience.AOT  Female
# 1    2    Kissiah     Lince      KissiahLince@datascience.AOT  Female
# 13  14      Ulric     Borel        UlricBorel@datascience.AOT    Male
# 14  15    Craggie  Spencers   CraggieSpencers@datascience.AOT    Male
# 21  22   Kristian  Mattacks  KristianMattacks@datascience.AOT    Male
#
#    loyalty_status  spend_2021 avg_rate
# 0            Gold     2822.87   $95.11
# 1            Gold     2330.12   $34.13
# 13           Gold     1828.70  $150.11
# 14           Gold     1898.91  $203.18
# 21           Gold     2456.62  $216.41

# %%
df[df['spend_2021'] > 3500].head()
# Out:
#     id first_name last_name                           email  gender  \
# 22  23     Jorgan      Erie      JorganErie@datascience.AOT    Male
# 23  24      Darci  Hotchkin   DarciHotchkin@datascience.AOT  Female
# 30  31     Stacee  Lowdiane  StaceeLowdiane@datascience.AOT    Male
# 33  34      Ailis  Stonuary   AilisStonuary@datascience.AOT  Female
# 34  35   Madeline     Tythe   MadelineTythe@datascience.AOT  Female
#
#    loyalty_status  spend_2021 avg_rate
# 22           Gold     3633.88  $189.88
# 23         Silver     4245.37   $49.30
# 30         Silver     3763.93   $55.74
# 33            NaN     4242.12  $240.74
# 34            NaN     3751.15  $159.12

# %%
df[(df['loyalty_status'] == 'Gold') & (df['spend_2021'] > 3500)].head()
# Out:
#     id first_name last_name                        email  gender  \
# 22  23     Jorgan      Erie   JorganErie@datascience.AOT    Male
# 45  46     Jemima     Kamen  JemimaKamen@datascience.AOT  Female
#
#    loyalty_status  spend_2021 avg_rate
# 22           Gold     3633.88  $189.88
# 45           Gold     4074.86   $37.72

# %%
df[df['loyalty_status'].isna()]
df = df.dropna()

# %%
# Out:
#     id first_name  last_name                             email    gender  \
# 0    1       Marj   Wasselin      MarjWasselin@datascience.AOT    Female
# 1    2    Kissiah      Lince      KissiahLince@datascience.AOT    Female
# 2    3  Margarita      Celle    MargaritaCelle@datascience.AOT    Female
# 4    5     Jelene     Ripper      JeleneRipper@datascience.AOT  Bigender
# 5    6        Tom  Mullender      TomMullender@datascience.AOT      Male
# ..  ..        ...        ...                               ...       ...
# 93  94     Billie   Steffens    BillieSteffens@datascience.AOT      Male
# 95  96     Hollie   Westwood    HollieWestwood@datascience.AOT    Female
# 96  97    Carroll     Harmes     CarrollHarmes@datascience.AOT      Male
# 97  98   Zacharie   Houlston  ZacharieHoulston@datascience.AOT      Male
# 98  99      Gerda     Jevons       GerdaJevons@datascience.AOT    Female
#
#    loyalty_status  spend_2021 avg_rate
# 0            Gold     2822.87   $95.11
# ...

# %%
from pandasql import sqldf

# %%
sqldf('''
select *
from df
limit 5
''')
# Out:
#    id first_name last_name                           email    gender  \
# 0   1       Marj  Wasselin    MarjWasselin@datascience.AOT    Female
# 1   2    Kissiah     Lince    KissiahLince@datascience.AOT    Female
# 2   3  Margarita     Celle  MargaritaCelle@datascience.AOT    Female
# 3   4        Nat   Richens      NatRichens@datascience.AOT    Female
# 4   5     Jelene    Ripper    JeleneRipper@datascience.AOT  Bigender
#
#   loyalty_status  spend_2021 avg_rate
# 0           Gold     2822.87   $95.11
# 1           Gold     2330.12   $34.13
# 2       Platnium     2797.42  $204.66
# 3           None     2487.10   $60.49
# 4         Silver     2370.85   $78.13

# %%
sqldf('''
select first_name, email, gender
from df
limit 5
''')
# Out:
#   first_name                           email    gender
# 0       Marj    MarjWasselin@datascience.AOT    Female
# 1    Kissiah    KissiahLince@datascience.AOT    Female
# 2  Margarita  MargaritaCelle@datascience.AOT    Female
# 3        Nat      NatRichens@datascience.AOT    Female
# 4     Jelene    JeleneRipper@datascience.AOT  Bigender

# %%
sqldf('''
select first_name AS 'Name', email, gender
from df
limit 5
''')
# Out:
#         Name                           email    gender
# 0       Marj    MarjWasselin@datascience.AOT    Female
# 1    Kissiah    KissiahLince@datascience.AOT    Female
# 2  Margarita  MargaritaCelle@datascience.AOT    Female
# 3        Nat      NatRichens@datascience.AOT    Female
# 4     Jelene    JeleneRipper@datascience.AOT  Bigender

# %%
df1 = pd.read_csv("data curation_assignment_data_1.csv")
df2 = pd.read_csv("data curation_assignment_data_2.csv")

# %%
df3 = pd.concat([df1, df2])
df3.head()
# Out:
#    id first_name    last_name                                     email  \
# 0   1       Rice      Shinton          Rice.Shinton@datascience.aot.com
# 1   2   Anatollo       Dinjes       Anatollo.Dinjes@datascience.aot.com
# 2   3   Giuseppe      Woosnam      Giuseppe.Woosnam@datascience.aot.com
# 3   4   Beatrice      Delafoy      Beatrice.Delafoy@datascience.aot.com
# 4   5   Bethanne  Adamthwaite  Bethanne.Adamthwaite@datascience.aot.com
#
#      gender loyalty_status            education average_spend_2021  \
# 0      Male            NaN        Master Degree            $174.93
# 1      Male            NaN  High School Diploma            $277.36
# 2      Male         Silver  High School Diploma            $266.70
# 3    Female            NaN  High School Diploma            $374.68
# 4  Bigender         Silver                  PhD            $339.74
#
#   total_spend_2021 most_traveled_city most_traveled_state
# 0        $3,867.11         Evansville                  IN
# ...

# %%
sqldf(
'''
select first_name, last_name, email, loyalty_status
from df3
''')
# Out:
#      first_name    last_name                                     email  \
# 0          Rice      Shinton          Rice.Shinton@datascience.aot.com
# 1      Anatollo       Dinjes       Anatollo.Dinjes@datascience.aot.com
# 2      Giuseppe      Woosnam      Giuseppe.Woosnam@datascience.aot.com
# 3      Beatrice      Delafoy      Beatrice.Delafoy@datascience.aot.com
# 4      Bethanne  Adamthwaite  Bethanne.Adamthwaite@datascience.aot.com
# ...         ...          ...                                       ...
# 2995      Ferdy       Harrad          Ferdy.Harrad@datascience.aot.com
# 2996      Vanya      Caulket         Vanya.Caulket@datascience.aot.com
# 2997     Emalee        Folke          Emalee.Folke@datascience.aot.com
# 2998     Lorine     Matyukon       Lorine.Matyukon@datascience.aot.com
# 2999       Otes       Linton           Otes.Linton@datascience.aot.com
#
#      loyalty_status
# 0              None
# 1              None
# 2            Silver
# 3              None
# ...

# %%
sqldf(
"""
select first_name, last_name, email, loyalty_status
from df3
where loyalty_status == 'Silver' 
"""

)
# Out:
#     first_name    last_name                                     email  \
# 0     Giuseppe      Woosnam      Giuseppe.Woosnam@datascience.aot.com
# 1     Bethanne  Adamthwaite  Bethanne.Adamthwaite@datascience.aot.com
# 2       Harley      Corteis        Harley.Corteis@datascience.aot.com
# 3     Marielle       Acland       Marielle.Acland@datascience.aot.com
# 4        Brook   Dronsfield      Brook.Dronsfield@datascience.aot.com
# ..         ...          ...                                       ...
# 790    Chantal      Kirvell       Chantal.Kirvell@datascience.aot.com
# 791   Lucienne         Petz         Lucienne.Petz@datascience.aot.com
# 792     Orelle      Manhare        Orelle.Manhare@datascience.aot.com
# 793  Frederico      Halahan     Frederico.Halahan@datascience.aot.com
# 794      Ferdy       Harrad          Ferdy.Harrad@datascience.aot.com
#
#     loyalty_status
# 0           Silver
# 1           Silver
# 2           Silver
# 3           Silver
# 4           Silver
# ...

# %%
sqldf(
'''
SeleCt first_name aS 'First Name', last_name As 'Last Name', email, loyalty_status
from df3
WHERE total_spend_2021 < 3000
limit 5
''')
# Out:
#   First Name    Last Name                                     email  \
# 0       Rice      Shinton          Rice.Shinton@datascience.aot.com
# 1   Anatollo       Dinjes       Anatollo.Dinjes@datascience.aot.com
# 2   Giuseppe      Woosnam      Giuseppe.Woosnam@datascience.aot.com
# 3   Beatrice      Delafoy      Beatrice.Delafoy@datascience.aot.com
# 4   Bethanne  Adamthwaite  Bethanne.Adamthwaite@datascience.aot.com
#
#   loyalty_status
# 0           None
# 1           None
# 2         Silver
# 3           None
# 4         Silver

# %%
sqldf(
'''
select loyalty_status AS 'Loyalty Status', education AS 'Education', total_spend_2021 AS 'Total Spend'
from df3
where most_traveled_state == 'NY'
''')
# Out:
#     Loyalty Status            Education Total Spend
# 0           Silver                  PhD   $3,861.61
# 1         Platnium      Bachelor Degree     $878.77
# 2           Silver         Some College   $3,342.98
# 3             None        Master Degree   $1,416.91
# 4             None      Bachelor Degree   $1,323.61
# ..             ...                  ...         ...
# 146           None  High School Diploma   $3,722.89
# 147           Gold      Bachelor Degree   $2,834.20
# 148           Gold      Bachelor Degree   $2,127.30
# 149           None        Master Degree   $1,097.52
# 150           None  High School Diploma   $2,701.73
#
# [151 rows x 3 columns]

# %%
df4 = sqldf(
'''
select loyalty_status AS 'Loyalty Status', education AS 'Education', total_spend_2021 AS 'Total Spend'
from df3
where most_traveled_state == 'NY'
''')
# Out:
#      Loyalty Status  Education  Total Spend
# 0             False      False        False
# 1             False      False        False
# 2             False      False        False
# 3              True      False        False
# 4              True      False        False
# ..              ...        ...          ...
# 146            True      False        False
# 147           False      False        False
# 148           False      False        False
# 149            True      False        False
# 150            True      False        False
#
# [151 rows x 3 columns]
